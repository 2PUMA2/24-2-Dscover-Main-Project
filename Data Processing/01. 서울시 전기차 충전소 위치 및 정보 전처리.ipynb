# %%
import pandas as pd

# %%
data = pd.read_csv(
    '한국환경공단_전기차 충전소 위치 및 운영정보(충전소 ID 포함)2017-2024.csv', 
    encoding='cp949')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21832\1946222635.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(

# %%
print(data.head())
# Out:
#    설치년도     시도   군구                   주소             충전소명 시설구분(대) 시설구분(소)  \
# 0  2017  서울특별시  강서구  서울특별시 강서구 가로공원로 189    가로공원로 지하공영주차장    주차시설   공영주차장
# 1  2017  서울특별시  강서구   서울특별시 강서구 강서로5길 50  곰달래문화복지센터 공영주차장    주차시설   공영주차장
# 2  2017  서울특별시  강서구  서울특별시 강서구 까치산로4길 22     볏골공원 지하공영주차장    주차시설   공영주차장
# 3  2017  서울특별시  강서구   서울특별시 강서구 우장산로 114      화곡6-1 공영주차장    주차시설   공영주차장
# 4  2017  서울특별시  관악구     서울특별시 관악구 관천로 98      신림동 제1공영주차장    주차시설   공영주차장
#
#   기종(대)     기종(소) 운영기관(대)  운영기관(소)     급속충전량            충전기타입 이용자제한  \
# 0    급속  급속(50kW)     환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보  이용가능
# 1    급속  급속(50kW)     환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보  이용가능
# 2    급속  급속(50kW)     환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보  이용가능
# 3    급속  급속(50kW)     환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보  이용가능
# 4    급속  급속(50kW)     환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보  이용가능
#
#                      위도경도
# 0  37.5372628,126.8383789
# 1  37.5289561,126.8490887
# 2  37.5419747,126.8444499
# ...

# %%
filtered_data = data[(data['시도'] == '서울특별시') & (data['설치년도']>=2017)]

# %%
filtered_data
# Out:
#         설치년도     시도   군구                   주소                    충전소명 시설구분(대)  \
# 0       2017  서울특별시  강서구  서울특별시 강서구 가로공원로 189           가로공원로 지하공영주차장    주차시설
# 1       2017  서울특별시  강서구   서울특별시 강서구 강서로5길 50         곰달래문화복지센터 공영주차장    주차시설
# 2       2017  서울특별시  강서구  서울특별시 강서구 까치산로4길 22            볏골공원 지하공영주차장    주차시설
# 3       2017  서울특별시  강서구   서울특별시 강서구 우장산로 114             화곡6-1 공영주차장    주차시설
# 4       2017  서울특별시  관악구     서울특별시 관악구 관천로 98             신림동 제1공영주차장    주차시설
# ...      ...    ...  ...                  ...                     ...     ...
# 361092  2024  서울특별시  강남구   서울특별시 강남구 압구정로 407  서울 강남 갤러리아백화점 명품관 EAST  공동주택시설
# 361093  2024  서울특별시  강남구   서울특별시 강남구 압구정로 343  서울 강남 갤러리아백화점 명품관 WEST  공동주택시설
# 361094  2024  서울특별시  강남구   서울특별시 강남구 압구정로 343  서울 강남 갤러리아백화점 명품관 WEST  공동주택시설
# 361095  2024  서울특별시  강남구   서울특별시 강남구 압구정로 343  서울 강남 갤러리아백화점 명품관 WEST  공동주택시설
# 361096  2024  서울특별시  강남구   서울특별시 강남구 압구정로 343  서울 강남 갤러리아백화점 명품관 WEST  공동주택시설
#
# ...

# %%
filtered_data.to_csv('서울시 전기차 충전소 위치 & 이용정보.csv',index=False)
